# %%
import datetime 
import pandas as pd
import pymongo
import warnings
import numpy as np
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
import re
from matplotlib.patches import FancyBboxPatch
import os
os.environ['CURL_CA_BUNDLE'] = ''
warnings.filterwarnings("ignore")
client = pymongo.MongoClient('10.128.96.25', 27017)
db = client["sentiment_news"]
sentiment_newsCollection = db["sentiment_newsCollection"]
sentiment_news_df = pd.DataFrame(list(sentiment_newsCollection.find()))
sentiment_news_df
# Out:
#                            _id  \
# 0     66b211e9527dab8fc76afa01
# 1     66b211e9527dab8fc76afa02
# 2     66b211e9527dab8fc76afa03
# 3     66b211e9527dab8fc76afa04
# 4     66b211e9527dab8fc76afa05
# ...                        ...
# 1010  66b211e9527dab8fc76afdf3
# 1011  66b211e9527dab8fc76afdf4
# 1012  66b211e9527dab8fc76afdf5
# 1013  66b211e9527dab8fc76afdf6
# 1014  66b211e9527dab8fc76afdf7
#
#                                                headline  \
# 0     Zebra Technologies CEO Shares Insights on Cons...
# 1     This Beaten-Down High-Yielding Dividend Stock ...
# 2           Should You Buy Nvidia Stock Before Aug. 28?
# 3             What Is the Dividend Payout for Enbridge?
# 4     Here Is What Top Semiconductor Stocks Said Abo...
# ...                                                 ...
# 1010  Caterpillar's (NYSE:CAT) Q2 Earnings Results: ...
# 1011  Stocks See Choppy Trading as Nerves Still Run ...
# 1012  US to invest $2.2 billion to overhaul national...
# 1013  Robinhood's second quarter to benefit from mem...
# 1014  Bitcoin's Unreliable Death Cross Is Looming Again
#
#                                                 alltext        date  \
# 0     In a post-earnings interview with yours truly,...  2024-08-01
# 1     American Tower (AMT -1.19%) has hit a speed bu...  2024-08-01
# 2     Shares of Nvidia (NVDA 12.81%) have more than ...  2024-08-01
# 3     Distributing dividends to shareholders for 69 ...  2024-08-01
# 4     In today's video, I discuss Taiwan Semiconduct...  2024-08-01
# ...                                                 ...         ...
# 1010  Construction equipment company Caterpillar (NY...  2024-08-06
# 1011  (Bloomberg) -- Stocks whipsawed in early tradi...  2024-08-06
# 1012  (Reuters) -The Biden administration said on Tu...  2024-08-06
# 1013  Wall Street expects Robinhood's (HOOD) revenue...  2024-08-06
# 1014  The bitcoin price is staring at the death cros...  2024-08-06
#
#              source                                                url  \
# 0              FOOL  https://www.fool.com/investing/2024/08/01/zebr...
# 1              FOOL  https://www.fool.com/investing/2024/08/01/this...
# 2              FOOL  https://www.fool.com/investing/2024/08/01/shou...
# 3              FOOL  https://www.fool.com/investing/2024/08/01/what...
# 4              FOOL  https://www.fool.com/investing/2024/08/01/here...
# ...             ...                                                ...
# 1010  FINANCE-YAHOO  https://finance.yahoo.com/news/caterpillars-ny...
# 1011  FINANCE-YAHOO  https://finance.yahoo.com/news/japan-stocks-po...
# 1012  FINANCE-YAHOO  https://finance.yahoo.com/news/us-invest-2-2-b...
# 1013  FINANCE-YAHOO  https://finance.yahoo.com/news/robinhoods-seco...
# 1014  FINANCE-YAHOO  https://finance.yahoo.com/news/bitcoins-unreli...
#
#                                                 tickers  \
# 0                [COVID, INFLATION, ZEBRA TECHNOLOGIES]
# 1                             [AMERICAN TOWER, S&P 500]
# 2                             [INTEL, NVIDIA, SOFTWARE]
# 3                                  [ENERGY, FINANCIALS]
# 4                                                    []
# ...                                                 ...
# 1010  [INDUSTRIALS, MACHINERY, MEDIA, MICROSOFT, NYS...
# 1011  [BANKS, DOW JONES, GOLD, GOLDMAN SACHS, INTEL,...
# 1012                                           [ENERGY]
# 1013                                 [CITIGROUP, MEDIA]
# 1014                                            [MEDIA]
#
#                                                positive  \
# 0     [3.1496796756982803, 3.1496796756982803, 61.83...
# 1                [76.40757427683899, 95.16984224319458]
# 2     [92.08784699440002, 57.01262921314029, 41.6662...
# 3                [78.06194126605988, 9.758884459733963]
# 4                                                    []
# ...                                                 ...
# 1010  [41.06370359659195, 34.64593514800072, 94.4951...
# 1011  [4.062511771917343, 77.1243691444397, 45.10577...
# 1012                                [85.82750260829926]
# 1013             [95.38196325302124, 9.360748529434204]
# 1014                               [3.5064704716205597]
#
#                                                negative  \
# 0     [91.74224138259888, 91.74224138259888, 1.40690...
# 1               [8.685826257403408, 2.7986738830804825]
# 2     [5.337639153003693, 14.439579422640449, 0.9837...
# 3               [1.3612563721835613, 4.275104403495789]
# 4                                                    []
# ...                                                 ...
# 1010  [2.405168581753969, 13.182383930931488, 2.0105...
# 1011  [93.90944838523865, 17.199310660362244, 44.115...
# 1012                               [2.2263148333877325]
# 1013           [1.8210148438811302, 25.420427322387695]
# 1014                                [64.96259570121765]
#
#                                                 neutral  \
# 0     [5.10808527469635, 5.10808527469635, 36.758421...
# 1              [14.906599053314753, 2.0314790308475494]
# 2     [2.5745153427124023, 28.547791369697627, 57.34...
# 3                [20.57680143043399, 85.96600890159607]
# 4                                                    []
# ...                                                 ...
# 1010  [56.53112232685089, 52.17168057958285, 3.49434...
# 1011  [2.0280417054891586, 5.676324293017387, 10.778...
# 1012                               [11.946183443069458]
# 1013             [2.7970196679234505, 65.2188241481781]
# 1014                               [31.530937552452087]
#
#                                                  status
# 0                        [negative, negative, positive]
# 1                                  [positive, positive]
# 2                         [positive, positive, neutral]
# 3                                   [positive, neutral]
# 4                                                    []
# ...                                                 ...
# 1010  [neutral, neutral, positive, neutral, negative...
# 1011  [negative, positive, positive, positive, posit...
# 1012                                         [positive]
# 1013                                [positive, neutral]
# 1014                                         [negative]
#
# [1015 rows x 11 columns]

# %%
import datetime 
import pandas as pd
import pymongo
import warnings
import numpy as np
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
import re
from matplotlib.patches import FancyBboxPatch
import os
os.environ['CURL_CA_BUNDLE'] = ''
warnings.filterwarnings("ignore")
client = pymongo.MongoClient('10.128.96.25', 27017)
db = client

# %%
db['sentiment_news']
# Out:
# Collection(Database(MongoClient(host=['10.128.96.25:27017'], document_class=dict, tz_aware=False, connect=True), 'sentiment_news'), 'sentiment_news')

# %%
pd.DataFrame(list(sentiment_newsCollection.find()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 pd.DataFrame(list(db.find()))
#
# File ~/.local/lib/python3.8/site-packages/pymongo/database.py:1652, in Database.__call__(self, *args, **kwargs)
#    1649 def __call__(self, *args, **kwargs):
#    1650     """This is only here so that some API misusages are easier to debug.
#    1651     """
# -> 1652     raise TypeError("'Database' object is not callable. If you meant to "
#    1653                     "call the '%s' method on a '%s' object it is "
#    1654                     "failing because no such method exists." % (
#    1655                         self.__name, self.__client.__class__.__name__))
#
# TypeError: 'Database' object is not callable. If you meant to call the 'find' method on a 'MongoClient' object it is failing because no such method exists.
